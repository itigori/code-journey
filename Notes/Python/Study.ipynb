# %% [markdown]
# # Python 列表
# ```python
# shopping_list = ["键盘", "键帽"]
#
# # 方法 => 对象.方法名()   函数 => 函数名(操作对象)
#
# #列表是可变的，其他不可变
# # 增加列表元素
# shopping_list.append("显示器")
# # 删除列表元素
# shopping_list.remove("显示器")
# # 求长度
# len(shopping_list)
# # 索引
# print(shopping_list[1]) # 从零开始数
# shopping_list[1] = "鼠标" # 直接索引赋值
# # max min sort函数都可使用
# ```

# %% [markdown]
# # Python 字典
# 字典用于存储键和值，键用来查找值
# ```python
# contact = {
#     "A" = "1234567"
#     "B" = "7654321"
# }
#
# # 获取键的值
# contact["A"]
#
# # 元组 tuple 元组可以放多个元素
# name_tuple = ("A", "32") # 不可变
#
# contact = {
#     ("A", "32") = "1234567"
# }
#
# # 添加值 如果键已存在，则元素会覆盖
# contact["C"] = "999"
# # 删除值 如果键不存在，则会报错
# del contact["A"]
# # 字典长度
# len(contact)
#
# contact.keys() # 返回所有键
# contact.values() # 返回所有值
# contact.items() # 返回所有键值对
# ```

# %% [markdown]
# # Python for循环
# for 变量名 in 可迭代对象
#
# ``` python
# temperature_list = [36.4, 37.0, 38.2, 37.5]
#
# for temperature in temperature_list:
#     if temperature >= 38:
#         print('Warning')
#
# for number in range(5, 10, 2) # range 由5到10，不包含10，第三value为步长
#
# ```

# %% [markdown]
# # Python while循环
# 重复执行直到条件不成立
# while 条件A: (可以直接填写布尔值)
#     行动B
#
# ``` python
# i = 0
# while i < len(list1):
#     print(list1[i])
#     i = i + 1
# ```

# %% [markdown]
# # Python 格式化字符串
# ```python
# # 花括号 format方法
# message = """
# A{0}B,
# A{1}B
# """.format(year, name)
#
# # f字符串
# message = f"""
# A{year}B,
# A{name}B
# """
#
# # 保留小数
# .2f #保留两位小数
# ```

# %% [markdown]
# # Python 函数
#
# ``` python
# def calculate_1:
#     central = 1
#     a = 2
#     print(f"{central + a}")
#
# calculate_1()
# ```
